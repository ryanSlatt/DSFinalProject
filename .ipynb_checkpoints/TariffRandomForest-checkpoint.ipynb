# %%
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import \
     (cross_validate,
      KFold,
      ShuffleSplit)
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler
#https://www.statsmodels.org/stable/mixed_linear.html

# %% [markdown]
# # Random Forest on tradeBalance, full dataset at HTS level, no controls

# %% [markdown]
# ## Load data, create dummy variables, scale data, train/test split

# %%
data = pd.read_csv("MLReadyCombinedDataset.csv",usecols = ["Country","Year","HTS8","tradeBalance"] )
# Out:
# C:\Users\iiski\AppData\Local\Temp\ipykernel_3324\2855526849.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("MLReadyCombinedDataset.csv",usecols = ["Country","Year","HTS8","tradeBalance"] )

# %%
data = data.dropna(subset = ['tradeBalance','Year'])

# %%
#Modeled after the example here: https://pandas.pydata.org/docs/user_guide/groupby.html
data['tradeBalance'] = data.groupby(['Country','HTS8'])['tradeBalance'].transform(lambda x: (x - x.mean()) / x.std())

# %%
#Drop NAs again because sclaing introduces NAs
data = data.dropna(subset = ['tradeBalance','Year'])

# %%
data = pd.get_dummies(data,columns = ["Country"])

# %%
y = data['tradeBalance']
X = data.drop(['tradeBalance'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Fitting the Random Forest and calculating RMSE

# %%
rf = RandomForestRegressor(random_state=42,max_depth = 5,verbose = 1)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed: 124.7min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   10.6s finished

# %%
forestMSE = ((y_pred-y_test)**2).sum()/len(y_pred)
forestMSE
# Out:
# 0.9198001877649564

# %%
forestRMSE = forestMSE**.5
forestRMSE
# Out:
# 0.9590621396786323

# %%
feature_importances = pd.DataFrame({
    "feature": X.columns,
    "importance": rf.feature_importances_
}).sort_values(by="importance", ascending=False)

# %%
feature_importances.head(20)
# Out:
#                           feature  importance
# 0                            Year    0.677912
# 43                  Country_China    0.134525
# 227             Country_Venezuela    0.079526
# 97                  Country_India    0.037474
# 1                            HTS8    0.024990
# 221  Country_United Arab Emirates    0.024957
# 103                 Country_Italy    0.007888
# 9               Country_Argentina    0.005304
# 28                 Country_Brazil    0.003637
# 80                Country_Germany    0.001483
# 228               Country_Vietnam    0.001400
# 165           Country_Philippines    0.000232
# 49             Country_Costa Rica    0.000198
# 15                Country_Bahamas    0.000186
# 161                Country_Panama    0.000147
# 60     Country_Dominican Republic    0.000077
# 213   Country_Trinidad and Tobago    0.000036
# 25                Country_Bolivia    0.000030
# 156       Country_North Macedonia    0.000000
# ...

# %% [markdown]
# # Attempt at Random Forest with all variables (tariff exemption indicators, etc.)

# %% [markdown]
# ## Load data, create dummy variables, establish X and y

# %%
data = pd.read_csv("MLReadyCombinedDataset.csv",usecols = list(range(2,35)))
#data = pd.read_csv("MLReadyCombinedDataset.csv",usecols = ["Country","Year","HTS8","tradeBalance"] )
# Out:
# C:\Users\iiski\AppData\Local\Temp\ipykernel_16744\1805118586.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("MLReadyCombinedDataset.csv",usecols = ["Country","Year","HTS8","tradeBalance"] )

# %%
data = data.dropna(subset = ['tradeBalance','Year'])

# %%
data
# Out:
#             Year      Country        HTS8  tradeBalance
# 0         1997.0  Afghanistan   2013060.0       62066.0
# 1         1997.0  Afghanistan   7051100.0       10615.0
# 2         1997.0  Afghanistan  10011000.0     2290359.0
# 3         1997.0  Afghanistan  17026000.0       15983.0
# 4         1997.0  Afghanistan  20099040.0       11041.0
# ...          ...          ...         ...           ...
# 14617557  2025.0     Zimbabwe  97031000.0       -2250.0
# 14617558  2025.0     Zimbabwe  97039000.0     -308843.0
# 14617559  2025.0     Zimbabwe  97051000.0       -8000.0
# 14617560  2025.0     Zimbabwe  98010010.0     -170086.0
# 14617561  2025.0     Zimbabwe  99999500.0     -492260.0
#
# [14614198 rows x 4 columns]

# %%
#GenAI used here
data['begin_effect_date'] = pd.to_datetime(data['begin_effect_date'])

data['begin_effect_date'] = data['begin_effect_date'].map(
    pd.Timestamp.toordinal,
    na_action='ignore'
)

data['end_effective_date'] = pd.to_datetime(data['end_effective_date'])

data['end_effective_date'] = data['end_effective_date'].map(
    pd.Timestamp.toordinal,
    na_action='ignore'
)

# %%
#Gen AI used here
# Random forests can handle NaN but not NaT. Need to convert
data['begin_effect_date'] = pd.to_numeric(data['begin_effect_date'],errors = 'coerce')
data['end_effective_date'] = pd.to_numeric(data['end_effective_date'],errors = 'coerce')

# %%
data.columns

# %%
#List of categorical columns we need dummies for
#catCols = ['Country','quantity_1_code', 'quantity_2_code', 'wto_binding_code',
#       'mfn_rate_type_code','gsp_indicator', 'gsp_ctry_excluded',
#       'apta_indicator', 'civil_air_indicator', 'nafta_canada_ind',
#       'nafta_mexico_ind','cbi_indicator','israel_fta_indicator', 'atpa_indicator', 'pharmaceutical_ind',
#       'dyes_indicator', 'col2_rate_type_code']

# %%
catCols = ['Country','quantity_1_code', 'quantity_2_code', 'wto_binding_code',
       'mfn_rate_type_code','gsp_indicator', 'gsp_ctry_excluded',
       'apta_indicator', 'nafta_canada_ind',
       'nafta_mexico_ind','cbi_indicator','israel_fta_indicator', 'atpa_indicator', 'col2_rate_type_code']

# %%
#HTS as dummies would be a mess
#Convert dates to numeric

# %%
#Dropping a few more variables due to memory issues
data = data.drop(['dyes_indicator','pharmaceutical_ind','civil_air_indicator'],axis=1)

# %%
data['tradeBalance'] = data.groupby(['Country','HTS8'])['tradeBalance'].transform(lambda x: (x - x.mean()) / x.std())

# %%
data
# Out:
#             Year      Country        HTS8  tradeBalance
# 0         1997.0  Afghanistan   2013060.0           NaN
# 1         1997.0  Afghanistan   7051100.0           NaN
# 2         1997.0  Afghanistan  10011000.0      0.707107
# 3         1997.0  Afghanistan  17026000.0           NaN
# 4         1997.0  Afghanistan  20099040.0           NaN
# ...          ...          ...         ...           ...
# 14617557  2025.0     Zimbabwe  97031000.0      0.656458
# 14617558  2025.0     Zimbabwe  97039000.0      0.604528
# 14617559  2025.0     Zimbabwe  97051000.0      0.722410
# 14617560  2025.0     Zimbabwe  98010010.0      0.491634
# 14617561  2025.0     Zimbabwe  99999500.0     -1.639156
#
# [14614198 rows x 4 columns]

# %%
data = pd.get_dummies(data,columns = catCols)
#data = pd.get_dummies(data,columns = ["Country"])

# %% [markdown]
# Drop Exports and Imports - they were used to calculate balance of trade, they are not really tariff related predictors

# %%
y = data['tradeBalance']
X = data.drop(['tradeBalance','Exports','Imports'],axis=1)
#X = data.drop(['tradeBalance'],axis=1)

# %% [markdown]
# ## Simple Training/Test Set

# %% [markdown]
# sample = data.sample(frac=0.01)

# %% [markdown]
# sample = sample.dropna(subset = ['tradeBalance'])

# %% [markdown]
# y = sample['tradeBalance']
# X = sample.drop(['tradeBalance','Exports','Imports'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestRegressor(random_state=42,max_depth = 5,verbose = 1)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed: 97.6min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    6.4s finished

# %%
forestMSE = ((y_pred-y_test)**2).sum()/len(y_pred)
forestMSE
# Out:
# np.float64(2.265094018588578e+16)
